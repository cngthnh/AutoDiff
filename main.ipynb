# %%
from AutoDiff import *

# %%
sess = Session()

# %%
sess.id
# Out:
# 0

# %%
x = Variable(0.9, name='x')
y = Variable(0.4, name='y')
z = (x * log(y) + 1.3) ** 2
z.compute()
# Out:
# 0.2259465387224418

# %%
print(x.grad)
# Out:
# -0.8710962332995489

# %%
print(y.grad)
# Out:
# 2.1390225359096724

# %%
g = drawGraph(z)
g

# %%
a = Variable([1., 2., 3.], name='a')
b = Variable([[5.], [3.], [8.]], name='b')
c = (a @ log(b) + 1.6) + 1.9

# %%
c.compute()
# Out:
# d:\OneDrive - VNU-HCMUS\Nhập môn học máy\AutoDiff\AutoDiff\core.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   for operand, grad in zip(np.array(node.operands, ndmin=1), np.array(grads, ndmin=1)):
# array([13.54498711])

# %%
a.grad
# Out:
# array([[1.60943791, 1.09861229, 2.07944154]])

# %%
sess.close()

# %%
x = Variable(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10476/3801083365.py in <module>
# ----> 1 x = Variable(5)
#
# d:\OneDrive - VNU-HCMUS\Nhập môn học máy\AutoDiff\AutoDiff\core.py in __init__(self, value, name, _transpose)
#      32     def __init__(self, value, name = None, _transpose = None):
#      33
# ---> 34         super().__init__(value, None)
#      35         if isinstance(value, list):
#      36             self.value = np.array(value)
#
# d:\OneDrive - VNU-HCMUS\Nhập môn học máy\AutoDiff\AutoDiff\core.py in __init__(self, value, grad)
#      10
#      11         if Session.getGraph() is None:
# ---> 12             raise ValueError("No graph found. Please create a session first.")
#      13         self.value = value
#      14         self.grad = grad
#
# ValueError: No graph found. Please create a session first.
