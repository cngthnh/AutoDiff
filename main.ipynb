# %%
from AutoDiff import *

# %%
sess = Session()

# %%
sess.id
# Out:
# 0

# %%
x = Variable(0.9, name='x')
y = Variable(0.4, name='y')
z = maximum((x * log(y) + 1.3) ** 2, exp(x))
z.compute()
# Out:
# 2.4596031111569494

# %%
print(x.grad)
# Out:
# 2.4596031111569494

# %%
print(y.grad)
# Out:
# 0.0

# %%
g = drawGraph(z)
g

# %%
a = Variable([1., 2., 3.], name='a')
b = Variable([[5.], [3.], [8.]], name='b')
c = (a @ log(b) + 1.6) + 1.9

# %%
c.compute()
# Out:
# array([13.54498711])

# %%
a.grad
# Out:
# array([[1.60943791, 1.09861229, 2.07944154]])

# %%
sess.close()
