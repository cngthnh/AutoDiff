# %%
from AutoDiff import *

# %%
sess = Session()

# %%
sess.id
# Out:
# 0

# %%
x = Variable([2.1, 1.2, 3.8], 'x')
y = Variable([[4.1], [2.2], [2.4]], 'y')
z = sigmoid(x) @ sigmoid(y)
z.compute()
# Out:
# array([2.46500925])

# %%
x.grad
# Out:
# array([0.09561018818670583, 0.16014938318061403, 0.01962237886871123],
#       dtype=object)

# %%
y.grad
# Out:
# array([[0.014287171850977824],
#        [0.06901377843365934],
#        [0.0745864427573643]], dtype=object)

# %%
x = Variable(0.1, name='x')
y = Variable(1.5, name='y')
z = maximum((x * log(y) + 1.7) ** 2, exp(x))
z.compute()
# Out:
# 3.0295021562957074

# %%
print(x.grad)
# Out:
# 1.411461758346392

# %%
print(y.grad)
# Out:
# 0.23207286810810887

# %%
d = Variable(3.0, name='d')
e = Variable(0.5, name='e')
f = (d / exp(e) - 0.15) ** log(2)
f.compute()
# Out:
# 1.4265984119506574

# %%
print(d.grad)
# Out:
# 0.3592275254570664

# %%
print(e.grad)
# Out:
# -1.077682576371199

# %%
g = drawGraph(z)
g

# %%
a = Variable([1., 2., 3.], name='a')
b = Variable([[5.], [3.], [8.]], name='b')
c = (a @ log(b) + 1.6) + 1.9

# %%
c.compute()
# Out:
# array([13.54498711])

# %%
a.grad
# Out:
# array([[1.60943791, 1.09861229, 2.07944154]])

# %%
sess.close()
